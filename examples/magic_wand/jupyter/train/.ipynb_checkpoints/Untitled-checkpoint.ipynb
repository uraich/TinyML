# %% [markdown]
# ## Read the stroke file ans sort the data into x and y arrays

# %%
strokeFilename = "strokes/digit_0.txt"

# %%
strokeFile = open(strokeFilename,"r")
strokeData = strokeFile.readlines()

# %%
print(strokeData)
# Out:
# ['-0.0469 0.1016\n', '-0.0469 0.1016\n', '-0.0469 0.1016\n', '-0.0469 0.1016\n', '-0.0469 0.1016\n', '-0.0469 0.1016\n', '-0.0469 0.1016\n', '-0.0469 0.1016\n', '-0.0547 0.1016\n', '-0.0469 0.1016\n', '-0.0469 0.1016\n', '-0.0547 0.1016\n', '-0.0547 0.1016\n', '-0.0547 0.1016\n', '-0.0547 0.1016\n', '-0.0547 0.1016\n', '-0.0547 0.1016\n', '-0.0547 0.1016\n', '-0.0547 0.1094\n', '-0.0469 0.1094\n', '-0.0391 0.1172\n', '-0.0312 0.1250\n', '-0.0156 0.1250\n', '0.0078 0.1250\n', '0.0312 0.1328\n', '0.0469 0.1328\n', '0.0703 0.1328\n', '0.0859 0.1328\n', '0.1016 0.1328\n', '0.1172 0.1328\n', '0.1250 0.1328\n', '0.1328 0.1328\n', '0.1484 0.1250\n', '0.1641 0.1172\n', '0.1719 0.1016\n', '0.1875 0.0781\n', '0.2031 0.0547\n', '0.2188 0.0234\n', '0.2266 -0.0156\n', '0.2422 -0.0547\n', '0.2422 -0.0938\n', '0.2500 -0.1406\n', '0.2500 -0.1797\n', '0.2422 -0.2188\n', '0.2344 -0.2578\n', '0.2188 -0.2969\n', '0.2031 -0.3281\n', '0.1797 -0.3594\n', '0.1562 -0.3828\n', '0.1328 -0.3984\n', '0.1094 -0.4
# ...

# %%
print(strokeData[0])
# Out:
# -0.0469 0.1016

# %%
xy = strokeData[0].split()
x = float(xy[0])
y = float(xy[1])

# %%
print(x,y)
# Out:
# -0.0469 0.1016
