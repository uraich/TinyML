# %%
import os

import numpy as np
import tensorflow as tf
# Out:
# 2023-09-27 14:04:25.174478: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
(x_train, y_train), _ = tf.keras.datasets.mnist.load_data()
x_train = x_train / 255.  # normalize pixel values to 0-1
x_train = x_train.astype(np.float32)

# %%
model = tf.keras.models.Sequential([
      tf.keras.layers.Input(shape=(28, 28), name="input"),
      tf.keras.layers.LSTM(20, return_sequences=True),
      tf.keras.layers.Flatten(),
      tf.keras.layers.Dense(10, activation=tf.nn.softmax, name="output")
  ])
model.compile(optimizer="adam",
                loss="sparse_categorical_crossentropy",
                metrics=["accuracy"])
model.summary()
# Out:
# 2023-09-27 14:04:38.948939: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3509 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 950M, pci bus id: 0000:01:00.0, compute capability: 5.0
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 28, 20)            3920
#
#  flatten (Flatten)           (None, 560)               0
#
#  output (Dense)              (None, 10)                5610
#
# =================================================================
# Total params: 9530 (37.23 KB)
# Trainable params: 9530 (37.23 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# my_train_lstm_model(model,20,x_train,y_train)

# %%
callback = tf.keras.callbacks.EarlyStopping(
      monitor="val_loss",
      patience=3)  #early stop if validation loss does not drop anymore
model.fit(x_train,
        y_train,
        epochs=20,
        validation_split=0.2,
        batch_size=32,
        callbacks=[callback])
# Out:
# Epoch 1/20
# 2023-09-27 14:04:47.927630: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8905
# 2023-09-27 14:04:47.999083: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f5ef4eb6690 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-09-27 14:04:47.999136: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce GTX 950M, Compute Capability 5.0
# 2023-09-27 14:04:48.007677: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-09-27 14:04:48.193130: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1500/1500 [==============================] - 11s 6ms/step - loss: 0.3677 - accuracy: 0.8903 - val_loss: 0.1799 - val_accuracy: 0.9453
# Epoch 2/20
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.1429 - accuracy: 0.9557 - val_loss: 0.1237 - val_accuracy: 0.9634
# Epoch 3/20
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.1041 - accuracy: 0.9689 - val_loss: 0.1066 - val_accuracy: 0.9682
# Epoch 4/20
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0851 - accuracy: 0.9743 - val_loss: 0.0926 - val_accuracy: 0.9737
# Epoch 5/20
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0713 - accuracy: 0.9782 - val_loss: 0.0835 - val_accuracy: 0.9766
# Epoch 6/20
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0635 - accuracy: 0.9802 - val_loss: 0.0781 - val_accuracy: 0.9778
# Epoch 7/20
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0560 - accuracy: 0.9830 - val_loss: 0.0722 - val_accuracy: 0.9789
# Epoch 8/20
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0512 - accuracy: 0.9840 - val_loss: 0.0680 - val_accuracy: 0.9811
# Epoch 9/20
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0466 - accuracy: 0.9855 - val_loss: 0.0705 - val_accuracy: 0.9798
# Epoch 10/20
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0432 - accuracy: 0.9864 - val_loss: 0.0679 - val_accuracy: 0.9801
# Epoch 11/20
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0400 - accuracy: 0.9874 - val_loss: 0.0734 - val_accuracy: 0.9788
# Epoch 12/20
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0373 - accuracy: 0.9884 - val_loss: 0.0646 - val_accuracy: 0.9817
# Epoch 13/20
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0342 - accuracy: 0.9893 - val_loss: 0.0639 - val_accuracy: 0.9819
# Epoch 14/20
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0328 - accuracy: 0.9895 - val_loss: 0.0648 - val_accuracy: 0.9807
# Epoch 15/20
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0313 - accuracy: 0.9899 - val_loss: 0.0630 - val_accuracy: 0.9821
# Epoch 16/20
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0290 - accuracy: 0.9908 - val_loss: 0.0615 - val_accuracy: 0.9833
# Epoch 17/20
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0269 - accuracy: 0.9916 - val_loss: 0.0658 - val_accuracy: 0.9817
# Epoch 18/20
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0260 - accuracy: 0.9915 - val_loss: 0.0631 - val_accuracy: 0.9823
# Epoch 19/20
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0238 - accuracy: 0.9925 - val_loss: 0.0634 - val_accuracy: 0.9823
