# %%
import struct

# %%
temperature = 25.3
print(int(temperature*100))
# Out:
# 2530

# %%
buf = struct.pack("<h",int(temperature * 100))

# %%
print(len(buf))
for i in range(len(buf)):
    print("0x{:02x}, ",buf[i])
# Out:
# 2
# 0x{:02x},  226
# 0x{:02x},  9
