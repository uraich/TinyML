# %% [markdown]
# # Read a binary image file and display it

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Read the image file into a byte array

# %%
raster = np.fromfile("digit_0.bin",dtype=np.uint8)

# %%
print(type(raster[0]))
print(raster[0])
# Out:
# <class 'numpy.uint8'>
# 0

# %%
# Use Matplotlib to show the image
plt.imshow(raster.reshape(32,32,3))
plt.show()
