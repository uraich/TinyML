# %% [markdown]
# # Passes values into the trained model and compares with true sin

# %% [markdown]
# Get the path to the non converted model

# %%
import sys
sys.path.insert(0,'/opt/ucc/projects/tinyML')
from tflite_micro.python.tflite_micro import runtime
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 3
#       1 import sys
#       2 sys.path.insert(0,'/opt/ucc/projects/tinyML')
# ----> 3 from tflite_micro.python.tflite_micro import runtime
#
# File /opt/ucc/projects/tinyML/tflite-micro/python/tflite_micro/__init__.py:22
#       1 # Copyright 2023 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      19 # made part of the public API in code outside of the tflm source tree is
#      20 # unsupported.
# ---> 22 from tflite_micro.python.tflite_micro import runtime
#      24 # Unambiguously identify the source used to build the package.
#      25 from tflite_micro.python.tflite_micro._version import __version__
#
# ModuleNotFoundError: No module named 'tflite_micro.python'

# %%
import os
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.python.platform import resource_loader
from tflite_micro.python.tflite_micro import runtime
# Out:
# 2023-09-02 21:27:53.359646: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-02 21:27:55.015868: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       3 import matplotlib.pyplot as plt
#       4 from tensorflow.python.platform import resource_loader
# ----> 5 from tflite_micro.python.tflite_micro import runtime
#
# ModuleNotFoundError: No module named 'tflite_micro'
